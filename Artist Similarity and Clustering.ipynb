# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/musicoset/releases.csv
# /kaggle/input/musicoset/albums.csv
# /kaggle/input/musicoset/artist_chart.csv
# /kaggle/input/musicoset/artists.csv
# /kaggle/input/musicoset/songs.csv
# /kaggle/input/musicoset/tracks.csv
# /kaggle/input/musicoset/album_chart.csv
# /kaggle/input/musicoset/acoustic_features.csv
# /kaggle/input/musicoset/album_pop.csv
# /kaggle/input/musicoset/artist_pop.csv
# /kaggle/input/musicoset/song_pop.csv
# /kaggle/input/musicoset/song_chart.csv
# /kaggle/input/musicoset/lyrics.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def optimizedata(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is:', start_mem)
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object and col_type != 'category':
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
artists = pd.read_csv('/kaggle/input/musicoset/artists.csv', delimiter='\t')
albums= pd.read_csv('/kaggle/input/musicoset/albums.csv', delimiter='\t')
releases = pd.read_csv('/kaggle/input/musicoset/releases.csv', delimiter='\t')
songs = pd.read_csv('/kaggle/input/musicoset/songs.csv', delimiter='\t')
tracks = pd.read_csv('/kaggle/input/musicoset/tracks.csv', delimiter='\t')

# %%
album_chart = pd.read_csv('/kaggle/input/musicoset/album_chart.csv', delimiter='\t')
album_pop =  pd.read_csv('/kaggle/input/musicoset/album_pop.csv', delimiter='\t')
artist_chart =  pd.read_csv('/kaggle/input/musicoset/artist_chart.csv', delimiter='\t')
artist_pop =  pd.read_csv('/kaggle/input/musicoset/artist_pop.csv', delimiter='\t')
song_chart =  pd.read_csv('/kaggle/input/musicoset/song_chart.csv', delimiter='\t')
song_pop =  pd.read_csv('/kaggle/input/musicoset/song_pop.csv', delimiter='\t')

# %%
acoustic_features = pd.read_csv('/kaggle/input/musicoset/acoustic_features.csv', delimiter='\t')
lyrics = pd.read_csv('/kaggle/input/musicoset/lyrics.csv', delimiter='\t')

# %%
acoustic_features.columns
# Out:
# Index(['song_id', 'duration_ms', 'key', 'mode', 'time_signature',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'valence', 'tempo'],
#       dtype='object')

# %%
lyrics.columns
# Out:
# Index(['song_id', 'lyrics'], dtype='object')

# %%
len(lyrics)
# Out:
# 20404

# %%
len(acoustic_features)
# Out:
# 20405

# %%
lyrics.isnull().sum()
# Out:
# song_id      0
# lyrics     741
# dtype: int64

# %%
optimizedata(artist_chart)
optimizedata(album_chart)
optimizedata(artist_pop)
#optimizedata(album_pop)
optimizedata(song_chart)
#optimizedata(song_pop)
# Out:
# Memory usage of dataframe is: 20.23247528076172
# Memory usage after optimization is: 5.48 MB
# Decreased by 72.9%
# Memory usage of dataframe is: 17.994277954101562
# Memory usage after optimization is: 5.79 MB
# Decreased by 67.8%
# Memory usage of dataframe is: 0.8821992874145508
# Memory usage after optimization is: 0.69 MB
# Decreased by 22.2%
# Memory usage of dataframe is: 9.55181884765625
# Memory usage after optimization is: 2.42 MB
# Decreased by 74.7%
#                        song_id  rank_score  peak_position  weeks_on_chart  \
# 0       3e9HZxeyfWwjeyPAMmWSSQ         100            100               7
# 1       5p7ujcrUXASCNwRaWNHR1C          99             99              11
# 2       2xLMifQCjDGFmkHkpNLD9h          98            100              20
# 3       3KkXRkHbMCARz0aVfEt68P          97             97               9
# 4       1rqqCSm0Qe4I9rUvWncaom          95             96              20
# ...                        ...         ...            ...             ...
# 250387  6vPS75nWOKkuH5WTLD8hDc           7             23               5
# 250388  2BCjoFA0nJlXBLRf3164bN           6              6               0
# 250389  7Gk1QKi2BAZCnrYlrYEDjC           4             11               4
# 250390  7rxev6ErpRE5VYaamjs4T3           2              2               0
# 250391  1TRvdHDqCIcTQpHTZbFttC           1              1               0
#
#               week
# 0       2018-12-29
# 1       2018-12-29
# 2       2018-12-29
# 3       2018-12-29
# 4       2018-12-29
# ...            ...
# 250387  1964-01-04
# 250388  1964-01-04
# 250389  1964-01-04
# 250390  1964-01-04
# 250391  1964-01-04
#
# [250392 rows x 5 columns]

# %%
optimizedata(acoustic_features)
# optimizedata(lyrics)
# optimizedata(artists)
# optimizedata(albums)
# optimizedata(releases)
# optimizedata(songs)
# optimizedata(tracks)
# Out:
# Memory usage of dataframe is: 2.1796112060546875
# Memory usage after optimization is: 1.19 MB
# Decreased by 45.6%
#                       song_id  duration_ms  key  mode  time_signature  \
# 0      3e9HZxeyfWwjeyPAMmWSSQ       207320    1     1               4
# 1      5p7ujcrUXASCNwRaWNHR1C       201661    6     1               4
# 2      2xLMifQCjDGFmkHkpNLD9h       312820    8     1               4
# 3      3KkXRkHbMCARz0aVfEt68P       158040    2     1               4
# 4      1rqqCSm0Qe4I9rUvWncaom       190947    5     1               4
# ...                       ...          ...  ...   ...             ...
# 20400  0yZsBLZVU2HTMlMqYvWevJ       133744    5     1               4
# 20401  30342v7I9sUoNC0Djnu1mW       125293    1     1               4
# 20402  5rkgbGIOTBGlKTAawWb06X       139400    4     0               4
# 20403  2MVPsa4S4r7Ii5lMh85E03       131333    9     1               4
# 20404  7wGbzk3aeGSpnsK2AQ7vzA       177136    5     0               4
#
#        acousticness  danceability    energy  instrumentalness  liveness  \
# 0          0.229004      0.716797  0.652832          0.000000  0.101013
# 1          0.297119      0.751953  0.488037          0.000009  0.093628
# 2          0.005131      0.833984  0.729980          0.000000  0.124023
# 3          0.556152      0.759766  0.479004          0.000000  0.070312
# 4          0.192993      0.579102  0.903809          0.000000  0.064026
# ...             ...           ...       ...               ...       ...
# 20400      0.386963      0.452881  0.646973          0.000000  0.450928
# 20401      0.646973      0.576172  0.541992          0.000000  0.172974
# 20402      0.144043      0.300049  0.743164          0.000000  0.385010
# 20403      0.791016      0.488037  0.830078          0.000728  0.155029
# 20404      0.862793      0.725098  0.616211          0.917969  0.144043
#
#         loudness  speechiness   valence     tempo
# 0      -5.632812     0.065796  0.412109  106.9375
# 1      -7.050781     0.070496  0.533203  136.0000
# 2      -3.714844     0.222046  0.446045  155.0000
# 3      -5.574219     0.046600  0.913086   89.9375
# 4      -2.728516     0.061798  0.681152   82.0000
# ...          ...          ...       ...       ...
# 20400  -7.984375     0.027695  0.728027   71.3750
# 20401  -8.367188     0.027603  0.507812  104.0625
# 20402 -10.007812     0.039307  0.952148  154.1250
# 20403  -4.488281     0.040192  0.950195  181.8750
# 20404  -3.298828     0.030396  0.594238  125.8125
#
# [20405 rows x 14 columns]

# %%
song_features = acoustic_features.merge(lyrics, on = 'song_id')
#optimizedata(song_features)
song_features
# Out:
#                       song_id  duration_ms  key  mode  time_signature  \
# 0      3e9HZxeyfWwjeyPAMmWSSQ       207320    1     1               4
# 1      5p7ujcrUXASCNwRaWNHR1C       201661    6     1               4
# 2      2xLMifQCjDGFmkHkpNLD9h       312820    8     1               4
# 3      3KkXRkHbMCARz0aVfEt68P       158040    2     1               4
# 4      1rqqCSm0Qe4I9rUvWncaom       190947    5     1               4
# ...                       ...          ...  ...   ...             ...
# 20399  0yZsBLZVU2HTMlMqYvWevJ       133744    5     1               4
# 20400  30342v7I9sUoNC0Djnu1mW       125293    1     1               4
# 20401  5rkgbGIOTBGlKTAawWb06X       139400    4     0               4
# 20402  2MVPsa4S4r7Ii5lMh85E03       131333    9     1               4
# 20403  7wGbzk3aeGSpnsK2AQ7vzA       177136    5     0               4
#
#        acousticness  danceability    energy  instrumentalness  liveness  \
# 0          0.229004      0.716797  0.652832          0.000000  0.101013
# 1          0.297119      0.751953  0.488037          0.000009  0.093628
# 2          0.005131      0.833984  0.729980          0.000000  0.124023
# 3          0.556152      0.759766  0.479004          0.000000  0.070312
# 4          0.192993      0.579102  0.903809          0.000000  0.064026
# ...             ...           ...       ...               ...       ...
# 20399      0.386963      0.452881  0.646973          0.000000  0.450928
# 20400      0.646973      0.576172  0.541992          0.000000  0.172974
# 20401      0.144043      0.300049  0.743164          0.000000  0.385010
# 20402      0.791016      0.488037  0.830078          0.000728  0.155029
# 20403      0.862793      0.725098  0.616211          0.917969  0.144043
#
#         loudness  speechiness   valence     tempo  \
# 0      -5.632812     0.065796  0.412109  106.9375
# 1      -7.050781     0.070496  0.533203  136.0000
# 2      -3.714844     0.222046  0.446045  155.0000
# 3      -5.574219     0.046600  0.913086   89.9375
# 4      -2.728516     0.061798  0.681152   82.0000
# ...          ...          ...       ...       ...
# 20399  -7.984375     0.027695  0.728027   71.3750
# 20400  -8.367188     0.027603  0.507812  104.0625
# 20401 -10.007812     0.039307  0.952148  154.1250
# 20402  -4.488281     0.040192  0.950195  181.8750
# 20403  -3.298828     0.030396  0.594238  125.8125
#
#                                                   lyrics
# 0      ['[Verse 1]\nThought I\'d end up with Sean\nBu...
# 1      ["[Verse 1]\nFound you when your heart was bro...
# 2      ['[Part I]\n\n[Intro: Drake]\nAstro, yeah\nSun...
# 3                                                    NaN
# 4      ["[Intro]\nHigh, high hopes\n\n[Chorus]\nHad t...
# ...                                                  ...
# 20399  ['The Trade Winds\nMiscellaneous\nNew York\'s ...
# 20400  ["There's nothing I can say\nThere's nothing I...
# 20401  ['825 ALL NIGHT – PAROV STELAR\n824 BIG JET PL...
# 20402                                                NaN
# 20403                                 ['[Instrumental]']
#
# [20404 rows x 15 columns]

# %%
song_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20404 entries, 0 to 20403
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           20404 non-null  object
#  1   duration_ms       20404 non-null  int32
#  2   key               20404 non-null  int8
#  3   mode              20404 non-null  int8
#  4   time_signature    20404 non-null  int8
#  5   acousticness      20404 non-null  float16
#  6   danceability      20404 non-null  float16
#  7   energy            20404 non-null  float16
#  8   instrumentalness  20404 non-null  float16
#  9   liveness          20404 non-null  float16
#  10  loudness          20404 non-null  float16
#  11  speechiness       20404 non-null  float16
#  12  valence           20404 non-null  float16
#  13  tempo             20404 non-null  float16
#  14  lyrics            19663 non-null  object
# dtypes: float16(9), int32(1), int8(3), object(2)
# memory usage: 817.1+ KB

# %%
df1 = song_features.merge(songs, on = 'song_id', suffixes=('', '_songs'))
#optimizedata(df1)
len(df1)
# Out:
# 20404

# %%
df2 = df1.merge(tracks, on = 'song_id', suffixes=('', '_tracks'))
optimizedata(df2)
len(df2)
# Out:
# Memory usage of dataframe is: 2.2184219360351562
# Memory usage after optimization is: 4.55 MB
# Decreased by -105.1%
# 20404

# %%
df3 = df2.merge(albums, on = 'album_id', suffixes=('', '_albums'))
optimizedata(df3)
len(df3)
# Out:
# Memory usage of dataframe is: 4.225254058837891
# Memory usage after optimization is: 4.72 MB
# Decreased by -11.6%
# 11300

# %%
df4 = df3.merge(releases, on = 'album_id', suffixes=('', '_releases'))
optimizedata(df4)
len(df4)
# Out:
# Memory usage of dataframe is: 4.7395477294921875
# Memory usage after optimization is: 4.94 MB
# Decreased by -4.2%
# 11300

# %%
df5 = df4.merge(artists, on = 'artist_id', suffixes=('', '_artists'))
optimizedata(df5)
len(df5)
# Out:
# Memory usage of dataframe is: 5.522125244140625
# Memory usage after optimization is: 5.35 MB
# Decreased by 3.2%
# 11296

# %%
df5.columns
# Out:
# Index(['song_id', 'duration_ms', 'key', 'mode', 'time_signature',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'valence', 'tempo', 'lyrics',
#        'song_name', 'billboard', 'artists', 'popularity', 'explicit',
#        'song_type', 'album_id', 'track_number', 'release_date',
#        'release_date_precision', 'name', 'billboard_albums', 'artists_albums',
#        'popularity_albums', 'total_tracks', 'album_type', 'image_url',
#        'artist_id', 'release_date_releases', 'release_date_precision_releases',
#        'name_artists', 'followers', 'popularity_artists', 'artist_type',
#        'main_genre', 'genres', 'image_url_artists'],
#       dtype='object')

# %%
dropcols= ['song_id', 'album_id', 'image_url_artists','artist_id' , 'image_url', 'release_date', 
           'track_number', 'release_date_precision' , 'total_tracks']
df5.drop(dropcols, axis= 1, inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11296 entries, 0 to 11295
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   duration_ms                      11296 non-null  int32
#  1   key                              11296 non-null  int8
#  2   mode                             11296 non-null  int8
#  3   time_signature                   11296 non-null  int8
#  4   acousticness                     11296 non-null  float16
#  5   danceability                     11296 non-null  float16
#  6   energy                           11296 non-null  float16
#  7   instrumentalness                 11296 non-null  float16
#  8   liveness                         11296 non-null  float16
#  9   loudness                         11296 non-null  float16
#  10  speechiness                      11296 non-null  float16
#  11  valence                          11296 non-null  float16
#  12  tempo                            11296 non-null  float16
#  13  lyrics                           11040 non-null  category
#  14  song_name                        11296 non-null  category
#  15  billboard                        11296 non-null  category
#  16  artists                          11296 non-null  category
#  17  popularity                       11296 non-null  int8
#  18  explicit                         11296 non-null  float16
#  19  song_type                        11296 non-null  category
#  20  name                             11296 non-null  category
#  21  billboard_albums                 11296 non-null  category
#  22  artists_albums                   11296 non-null  category
#  23  popularity_albums                11296 non-null  int8
#  24  album_type                       11296 non-null  category
#  25  release_date_releases            11296 non-null  category
#  26  release_date_precision_releases  11296 non-null  category
#  27  name_artists                     11296 non-null  category
#  28  followers                        11296 non-null  float32
#  29  popularity_artists               11296 non-null  int8
#  30  artist_type                      11296 non-null  category
#  31  main_genre                       11296 non-null  category
#  32  genres                           11296 non-null  category
# dtypes: category(15), float16(10), float32(1), int32(1), int8(6)
# memory usage: 3.6 MB

# %%
df5.sample(20)
# Out:
#        duration_ms  key  mode  time_signature  acousticness  danceability  \
# 3118        227920    1     1               4      0.316895      0.402100
# 3460        284200    5     0               4      0.033905      0.950195
# 10690       221240   10     1               4      0.099487      0.841797
# 9166        190080    5     0               4      0.529785      0.530762
# 9769        161560    4     1               4      0.036591      0.797852
# 3130        191373    6     1               5      0.000106      0.310059
# 1880        199187    5     0               4      0.001200      0.523926
# 9057        195720    0     1               4      0.427002      0.410889
# 8295        247067    7     1               4      0.505859      0.579102
# 1695        196920    1     0               4      0.016998      0.710938
# 3787        258400   11     0               4      0.257080      0.629883
# 10547       151333    9     1               4      0.252930      0.655762
# 10203       249160    5     1               4      0.010498      0.573242
# 10048       172400    0     1               4      0.685059      0.670898
# 1227        158293    3     1               4      0.155029      0.686035
# 9248        187213    2     1               4      0.130005      0.699219
# 484         232852    6     0               4      0.720215      0.678223
# 1705        323933    7     1               3      0.142944      0.616211
# 6976        242707    5     1               4      0.198975      0.720215
# 1809        242427    9     1               4      0.044586      0.629883
#
#          energy  instrumentalness  liveness   loudness  ...  \
# 3118   0.816895          0.000000  0.104980  -3.755859  ...
# 3460   0.665039          0.000000  0.045288  -4.285156  ...
# 10690  0.542969          0.000000  0.054810  -5.273438  ...
# 9166   0.673828          0.000095  0.036804  -7.312500  ...
# 9769   0.646973          0.050995  0.167969 -11.000000  ...
# 3130   0.939941          0.000002  0.204956  -3.394531  ...
# 1880   0.877930          0.000000  0.098022  -3.107422  ...
# 9057   0.374023          0.000010  0.154053 -14.031250  ...
# 8295   0.772949          0.000021  0.187988  -7.199219  ...
# 1695   0.881836          0.000000  0.111023  -2.769531  ...
# 3787   0.520020          0.000000  0.057709  -8.164062  ...
# 10547  0.594238          0.000905  0.119019 -10.992188  ...
# 10203  0.934082          0.000073  0.318115  -3.376953  ...
# 10048  0.333984          0.000000  0.069397  -9.125000  ...
# 1227   0.815918          0.000000  0.251953  -5.953125  ...
# 9248   0.641113          0.000218  0.060089  -7.562500  ...
# 484    0.400879          0.000000  0.117981  -8.406250  ...
# 1705   0.741211          0.000000  0.346924  -4.156250  ...
# 6976   0.879883          0.024597  0.086487  -8.984375  ...
# 1809   0.876953          0.000000  0.112976  -4.105469  ...
#
#        popularity_albums   album_type  release_date_releases  \
# 3118                  57        album                   1991
# 3460                  81        album             2000-05-23
# 10690                 68        album             2009-01-01
# 9166                  36        album             1969-12-15
# 9769                  50        album             1995-06-06
# 3130                  54        album             2002-07-22
# 1880                  67        album             2008-06-17
# 9057                  68        album             1969-06-17
# 8295                  57        album                   1973
# 1695                  71        album                 out/20
# 3787                  32        album                   1997
# 10547                 68        album                 fev/70
# 10203                 28        album             2006-07-11
# 10048                 56        album                   1964
# 1227                  64        album             2011-07-11
# 9248                  65        album             1969-01-05
# 484                   81        album             2017-10-20
# 1705                  60        album             2010-01-01
# 6976                  53        album             1980-08-01
# 1809                  63  compilation             2015-06-16
#
#       release_date_precision_releases                  name_artists  \
# 3118                             year                   Diamond Rio
# 3460                              day                        Eminem
# 10690                             day                  Mariah Carey
# 9166                              day                  The Winstons
# 9769                              day                    The McCoys
# 3130                              day                  TRUSTcompany
# 1880                              day                    Katy Perry
# 9057                              day                 Elvis Presley
# 8295                             year                    The O'Jays
# 1695                             year                      Maroon 5
# 3787                             year                    Sam Salter
# 10547                           month                  Van Morrison
# 10203                             day              Cheyenne Kimball
# 10048                            year                Dionne Warwick
# 1227                              day                   Chris Young
# 9248                              day  Creedence Clearwater Revival
# 484                               day                   Niall Horan
# 1705                              day                         Ne-Yo
# 6976                              day                    Paul Simon
# 1809                              day                    Tim McGraw
#
#         followers popularity_artists  artist_type            main_genre  \
# 3118     394776.0                 61         band  contemporary country
# 3460   29084504.0                 94       rapper       detroit hip hop
# 10690   4682308.0                 81       singer             dance pop
# 9166       3318.0                 30         band                     -
# 9769      15728.0                 46            -    brill building pop
# 3130      62559.0                 49         band         alabama metal
# 1880   13627543.0                 89       singer             dance pop
# 9057    3328510.0                 81       singer         rock-and-roll
# 8295     519673.0                 64         band          classic soul
# 1695   19722252.0                 89         band                   pop
# 3787      11232.0                 25       singer        new jack swing
# 10547   1244987.0                 77       singer          classic rock
# 10203     15979.0                 24       singer         post-teen pop
# 10048    388011.0                 65       singer       adult standards
# 1227    1545836.0                 74       singer  contemporary country
# 9248    2850682.0                 81         band            album rock
# 484     4014957.0                 78       singer        australian pop
# 1705    4720693.0                 81       singer             dance pop
# 6976    1075140.0                 74       singer          classic rock
# 1809    2803823.0                 77       singer  contemporary country
#
#                                                   genres
# 3118   ['contemporary country', 'country', 'country g...
# 3460     ['detroit hip hop', 'g funk', 'hip hop', 'rap']
# 10690  ['dance pop', 'pop', 'r&b', 'urban contemporary']
# 9166                                                  []
# 9769   ['brill building pop', 'bubblegum pop', 'class...
# 3130   ['alabama metal', 'alternative metal', 'nu met...
# 1880               ['dance pop', 'pop', 'post-teen pop']
# 9057                     ['rock-and-roll', 'rockabilly']
# 8295   ['classic soul', 'disco', 'funk', 'motown', 'p...
# 1695                                             ['pop']
# 3787                           ['new jack swing', 'r&b']
# 10547  ['classic rock', 'folk', 'folk rock', 'folk-po...
# 10203                                  ['post-teen pop']
# 10048  ['adult standards', 'brill building pop', 'dis...
# 1227   ['contemporary country', 'country', 'country r...
# 9248   ['album rock', 'classic rock', 'rock', 'roots ...
# 484    ['australian pop', 'dance pop', 'neo mellow', ...
# 1705   ['dance pop', 'pop', 'pop rap', 'r&b', 'urban ...
# 6976   ['classic rock', 'folk', 'folk rock', 'folk-po...
# 1809   ['contemporary country', 'country', 'country r...
#
# [20 rows x 33 columns]

# %%
df5.isnull().sum()
# Out:
# duration_ms                          0
# key                                  0
# mode                                 0
# time_signature                       0
# acousticness                         0
# danceability                         0
# energy                               0
# instrumentalness                     0
# liveness                             0
# loudness                             0
# speechiness                          0
# valence                              0
# tempo                                0
# lyrics                             256
# song_name                            0
# billboard                            0
# artists                              0
# popularity                           0
# explicit                             0
# song_type                            0
# name                                 0
# billboard_albums                     0
# artists_albums                       0
# popularity_albums                    0
# album_type                           0
# release_date_releases                0
# release_date_precision_releases      0
# name_artists                         0
# followers                            0
# popularity_artists                   0
# artist_type                          0
# main_genre                           0
# genres                               0
# dtype: int64
