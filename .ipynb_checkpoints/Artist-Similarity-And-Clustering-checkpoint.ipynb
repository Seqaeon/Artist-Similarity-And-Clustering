# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score, davies_bouldin_score

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
albums=pd.read_csv('albums.csv', delimiter='\t') 
artists=pd.read_csv('artists.csv', delimiter='\t')
releases=pd.read_csv('releases.csv', delimiter='\t')
songs=pd.read_csv('songs.csv', delimiter='\t')
tracks=pd.read_csv('tracks.csv', delimiter='\t')

# %%
acoustic_features = pd.read_csv('acoustic_features.csv', delimiter='\t')
lyrics = pd.read_csv('lyrics.csv', delimiter='\t')

# %%
print(" The columns types are \n{}".format(albums.dtypes)) 
print("----------------------------")
print("The dimension of the data is {}".format(albums.shape))
print("----------------------------")
print("The count of missing values in each column is \n{}".format(albums.isnull().sum()))
print("----------------------------")
print("The count of duplicates in the data is \n{}".format(albums.duplicated().sum()))
print("------------- ---------------")
albums.head()
# Out:
#  The columns types are
# album_id        object
# name            object
# billboard       object
# artists         object
# popularity       int64
# total_tracks     int64
# album_type      object
# image_url       object
# dtype: object
# ----------------------------
# The dimension of the data is (26519, 8)
# ----------------------------
# The count of missing values in each column is
# album_id        0
# name            0
# billboard       0
# artists         0
# popularity      0
# total_tracks    0
# album_type      0
# image_url       0
# dtype: int64
# ----------------------------
# The count of duplicates in the data is
# 0
# ------------- ---------------
#                  album_id                                               name  \
# 0  5n1GSzC1Reao29ScnpLYqp                                      Dying To Live
# 1  6UYZEYjpN1DYRW0kqFy9ZE                                      Championships
# 2  7uVimUILdzSZG4KKKWToq0                 Christmas (Deluxe Special Edition)
# 3  35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 4  41GuZcammIkupMPKH2OJ6I                                         ASTROWORLD
#
#                            billboard  \
# 0                      Dying To Live
# 1                      Championships
# 2                          Christmas
# 3  Spider-Man: Into The Spider-Verse
# 4                         ASTROWORLD
#
#                                          artists  popularity  total_tracks  \
# 0      {'46SHBwWsqBkxI7EeeBEQG7': 'Kodak Black'}          83            16
# 1        {'20sxb77xiYeusSH8cVdatc': 'Meek Mill'}          85            19
# 2    {'1GxkXlMwML1oSg5eLPiAz3': 'Michael Bublé'}          60            20
# 3  {'0LyfQWJT6nXafLPZqxe9Of': 'Various Artists'}          92            13
# 4     {'0Y5tJX1MQlPlqiwlOH1tJY': 'Travis Scott'}          91            17
#
#     album_type                                          image_url
# 0        album  https://i.scdn.co/image/db2133234d458f432ca207...
# 1        album  https://i.scdn.co/image/77eb7c17cafe5503c58661...
# 2        album  https://i.scdn.co/image/2d6ee8d4fb5a45abf35cd3...
# 3  compilation  https://i.scdn.co/image/3aa37254a41cf96e815725...
# 4        album  https://i.scdn.co/image/cdca7dc20c778ada42fb18...

# %%
print(" The columns types are \n{}".format(artists.dtypes)) 
print("----------------------------")
print("The dimension of the data is {}".format(artists.shape))
print("----------------------------")
print("The count of missing values in each column is \n{}".format(artists.isnull().sum()))
print("----------------------------")
print("The count of duplicates in the data is \n{}".format(artists.duplicated().sum()))
print("------------- ---------------")
artists.head()
# Out:
#  The columns types are
# artist_id       object
# name            object
# followers      float64
# popularity       int64
# artist_type     object
# main_genre      object
# genres          object
# image_url       object
# dtype: object
# ----------------------------
# The dimension of the data is (11518, 8)
# ----------------------------
# The count of missing values in each column is
# artist_id      0
# name           0
# followers      2
# popularity     0
# artist_type    0
# main_genre     0
# genres         0
# image_url      0
# dtype: int64
# ----------------------------
# The count of duplicates in the data is
# 0
# ------------- ---------------
#                 artist_id           name   followers  popularity artist_type  \
# 0  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande  34554242.0          96      singer
# 1  26VFTg2z8YR0cCuwLzESi2         Halsey   7368242.0          90      singer
# 2  0Y5tJX1MQlPlqiwlOH1tJY   Travis Scott   6313709.0          94      rapper
# 3  246dkjvS1zLTtiykXe5h60    Post Malone  16737002.0          96      rapper
# 4  1zNqQNIdeOUZHb8zbZRFMX       Swae Lee    483032.0          89      singer
#
#    main_genre                                             genres  \
# 0   dance pop              ['dance pop', 'pop', 'post-teen pop']
# 1   dance pop  ['dance pop', 'electropop', 'etherpop', 'indie...
# 2         pop                          ['pop', 'pop rap', 'rap']
# 3     dfw rap                          ['dfw rap', 'pop', 'rap']
# 4  trap music                                     ['trap music']
#
#                                            image_url
# 0  https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 1  https://i.scdn.co/image/22a5f3d8c42bc7cb55215e...
# 2  https://i.scdn.co/image/dc5eba5e032c2e5bc4d42c...
# 3  https://i.scdn.co/image/f9d8b742b66609f12da023...
# 4  https://i.scdn.co/image/a177469870b41f7e17e3b5...

# %%
print(" The columns types are \n{}".format(releases.dtypes)) 
print("----------------------------")
print("The dimension of the data is {}".format(releases.shape))
print("----------------------------")
print("The count of missing values in each column is \n{}".format(releases.isnull().sum()))
print("----------------------------")
print("The count of duplicates in the data is \n{}".format(releases.duplicated().sum()))
print("------------- ---------------")
releases.head()
# Out:
#  The columns types are
# artist_id                 object
# album_id                  object
# release_date              object
# release_date_precision    object
# dtype: object
# ----------------------------
# The dimension of the data is (26522, 4)
# ----------------------------
# The count of missing values in each column is
# artist_id                 0
# album_id                  0
# release_date              0
# release_date_precision    0
# dtype: int64
# ----------------------------
# The count of duplicates in the data is
# 0
# ------------- ---------------
#                 artist_id                album_id release_date  \
# 0  46SHBwWsqBkxI7EeeBEQG7  5n1GSzC1Reao29ScnpLYqp   2018-12-14
# 1  20sxb77xiYeusSH8cVdatc  6UYZEYjpN1DYRW0kqFy9ZE   2018-11-30
# 2  1GxkXlMwML1oSg5eLPiAz3  7uVimUILdzSZG4KKKWToq0   2012-11-09
# 3  0LyfQWJT6nXafLPZqxe9Of  35s58BRTGAEWztPo9WqCIs   2018-12-14
# 4  0Y5tJX1MQlPlqiwlOH1tJY  41GuZcammIkupMPKH2OJ6I   2018-08-03
#
#   release_date_precision
# 0                    day
# 1                    day
# 2                    day
# 3                    day
# 4                    day

# %%
print(" The columns types are \n{}".format(songs.dtypes)) 
print("----------------------------")
print("The dimension of the data is {}".format(songs.shape))
print("----------------------------")
print("The count of missing values in each column is \n{}".format(songs.isnull().sum()))
print("----------------------------")
print("The count of duplicates in the data is \n{}".format(songs.duplicated().sum()))
print("------------- ---------------")
songs.head()
# Out:
#  The columns types are
# song_id       object
# song_name     object
# billboard     object
# artists       object
# popularity     int64
# explicit        bool
# song_type     object
# dtype: object
# ----------------------------
# The dimension of the data is (20405, 7)
# ----------------------------
# The count of missing values in each column is
# song_id       0
# song_name     0
# billboard     0
# artists       0
# popularity    0
# explicit      0
# song_type     0
# dtype: int64
# ----------------------------
# The count of duplicates in the data is
# 0
# ------------- ---------------
#                   song_id                                      song_name  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ                                  thank u, next
# 1  5p7ujcrUXASCNwRaWNHR1C                                     Without Me
# 2  2xLMifQCjDGFmkHkpNLD9h                                     SICKO MODE
# 3  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 4  1rqqCSm0Qe4I9rUvWncaom                                     High Hopes
#
#                                            billboard  \
# 0                 ('Thank U, Next', 'Ariana Grande')
# 1                           ('Without Me', 'Halsey')
# 2                     ('Sicko Mode', 'Travis Scott')
# 3  ('Sunflower (Spider-Man: Into The Spider-Verse...
# 4              ('High Hopes', 'Panic! At The Disco')
#
#                                              artists  popularity  explicit  \
# 0        {'66CXWjxzNUsdJxJ2JdwvnR': 'Ariana Grande'}          86      True
# 1               {'26VFTg2z8YR0cCuwLzESi2': 'Halsey'}          87      True
# 2         {'0Y5tJX1MQlPlqiwlOH1tJY': 'Travis Scott'}          85      True
# 3  {'246dkjvS1zLTtiykXe5h60': 'Post Malone', '1zN...          92     False
# 4  {'20JZFwl6HVl6yg8a4H3ZqK': 'Panic! At The Disco'}          86     False
#
#        song_type
# 0           Solo
# 1           Solo
# 2           Solo
# 3  Collaboration
# 4           Solo

# %%
print(" The columns types are \n{}".format(tracks.dtypes)) 
print("----------------------------")
print("The dimension of the data is {}".format(tracks.shape))
print("----------------------------")
print("The count of missing values in each column is \n{}".format(tracks.isnull().sum()))
print("----------------------------")
print("The count of duplicates in the data is \n{}".format(tracks.duplicated().sum()))
print("------------- ---------------")
tracks.head()
# Out:
#  The columns types are
# song_id                   object
# album_id                  object
# track_number               int64
# release_date              object
# release_date_precision    object
# dtype: object
# ----------------------------
# The dimension of the data is (20405, 5)
# ----------------------------
# The count of missing values in each column is
# song_id                   0
# album_id                  0
# track_number              0
# release_date              0
# release_date_precision    0
# dtype: int64
# ----------------------------
# The count of duplicates in the data is
# 0
# ------------- ---------------
#                   song_id                album_id  track_number release_date  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ  2fYhqwDWXjbpjaIJPEfKFw            11   2019-02-08
# 1  5p7ujcrUXASCNwRaWNHR1C  0zzrCTzvL4ZmR42xF46Afm             1   2018-10-04
# 2  2xLMifQCjDGFmkHkpNLD9h  41GuZcammIkupMPKH2OJ6I             3   2018-08-03
# 3  3KkXRkHbMCARz0aVfEt68P  35s58BRTGAEWztPo9WqCIs             2   2018-12-14
# 4  1rqqCSm0Qe4I9rUvWncaom  6ApYSpXF8GxZAgBTHDzYge             4   2018-06-22
#
#   release_date_precision
# 0                    day
# 1                    day
# 2                    day
# 3                    day
# 4                    day

# %%
song_features = acoustic_features.merge(lyrics, on = 'song_id')
song_features
# Out:
#                       song_id  duration_ms  key  mode  time_signature  \
# 0      3e9HZxeyfWwjeyPAMmWSSQ       207320    1     1               4
# 1      5p7ujcrUXASCNwRaWNHR1C       201661    6     1               4
# 2      2xLMifQCjDGFmkHkpNLD9h       312820    8     1               4
# 3      3KkXRkHbMCARz0aVfEt68P       158040    2     1               4
# 4      1rqqCSm0Qe4I9rUvWncaom       190947    5     1               4
# ...                       ...          ...  ...   ...             ...
# 20399  0yZsBLZVU2HTMlMqYvWevJ       133744    5     1               4
# 20400  30342v7I9sUoNC0Djnu1mW       125293    1     1               4
# 20401  5rkgbGIOTBGlKTAawWb06X       139400    4     0               4
# 20402  2MVPsa4S4r7Ii5lMh85E03       131333    9     1               4
# 20403  7wGbzk3aeGSpnsK2AQ7vzA       177136    5     0               4
#
#        acousticness  danceability  energy  instrumentalness  liveness  \
# 0           0.22900         0.717   0.653          0.000000    0.1010
# 1           0.29700         0.752   0.488          0.000009    0.0936
# 2           0.00513         0.834   0.730          0.000000    0.1240
# 3           0.55600         0.760   0.479          0.000000    0.0703
# 4           0.19300         0.579   0.904          0.000000    0.0640
# ...             ...           ...     ...               ...       ...
# 20399       0.38700         0.453   0.647          0.000000    0.4510
# 20400       0.64700         0.576   0.542          0.000000    0.1730
# 20401       0.14400         0.300   0.743          0.000000    0.3850
# 20402       0.79100         0.488   0.830          0.000728    0.1550
# 20403       0.86300         0.725   0.616          0.918000    0.1440
#
#        loudness  speechiness  valence    tempo  \
# 0        -5.634       0.0658    0.412  106.966
# 1        -7.050       0.0705    0.533  136.041
# 2        -3.714       0.2220    0.446  155.008
# 3        -5.574       0.0466    0.913   89.911
# 4        -2.729       0.0618    0.681   82.014
# ...         ...          ...      ...      ...
# 20399    -7.985       0.0277    0.728   71.357
# 20400    -8.371       0.0276    0.508  104.083
# 20401   -10.005       0.0393    0.952  154.180
# 20402    -4.487       0.0402    0.950  181.869
# 20403    -3.299       0.0304    0.594  125.817
#
#                                                   lyrics
# 0      ['[Verse 1]\nThought I\'d end up with Sean\nBu...
# 1      ["[Verse 1]\nFound you when your heart was bro...
# 2      ['[Part I]\n\n[Intro: Drake]\nAstro, yeah\nSun...
# 3                                                    NaN
# 4      ["[Intro]\nHigh, high hopes\n\n[Chorus]\nHad t...
# ...                                                  ...
# 20399  ['The Trade Winds\nMiscellaneous\nNew York\'s ...
# 20400  ["There's nothing I can say\nThere's nothing I...
# 20401  ['825 ALL NIGHT – PAROV STELAR\n824 BIG JET PL...
# 20402                                                NaN
# 20403                                 ['[Instrumental]']
#
# [20404 rows x 15 columns]

# %%
df1 = song_features.merge(songs, on = 'song_id', suffixes=('', '_songs'))
len(df1)
# Out:
# 20404

# %%
df2 = df1.merge(tracks, on = 'song_id', suffixes=('', '_tracks'))
len(df2)
# Out:
# 20404

# %%
df3 = df2.merge(albums, on = 'album_id', suffixes=('', '_albums'))
len(df3)
# Out:
# 11300

# %%
df4 = df3.merge(releases, on = 'album_id', suffixes=('', '_releases'))
len(df4)
# Out:
# 11300

# %%
df5 = df4.merge(artists, on = 'artist_id', suffixes=('', '_artists'))
len(df5)
# Out:
# 11296

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11296 entries, 0 to 11295
# Data columns (total 42 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   song_id                          11296 non-null  object
#  1   duration_ms                      11296 non-null  int64
#  2   key                              11296 non-null  int64
#  3   mode                             11296 non-null  int64
#  4   time_signature                   11296 non-null  int64
#  5   acousticness                     11296 non-null  float64
#  6   danceability                     11296 non-null  float64
#  7   energy                           11296 non-null  float64
#  8   instrumentalness                 11296 non-null  float64
#  9   liveness                         11296 non-null  float64
#  10  loudness                         11296 non-null  float64
#  11  speechiness                      11296 non-null  float64
#  12  valence                          11296 non-null  float64
#  13  tempo                            11296 non-null  float64
#  14  lyrics                           11040 non-null  object
#  15  song_name                        11296 non-null  object
#  16  billboard                        11296 non-null  object
#  17  artists                          11296 non-null  object
#  18  popularity                       11296 non-null  int64
#  19  explicit                         11296 non-null  bool
#  20  song_type                        11296 non-null  object
#  21  album_id                         11296 non-null  object
#  22  track_number                     11296 non-null  int64
#  23  release_date                     11296 non-null  object
#  24  release_date_precision           11296 non-null  object
#  25  name                             11296 non-null  object
#  26  billboard_albums                 11296 non-null  object
#  27  artists_albums                   11296 non-null  object
#  28  popularity_albums                11296 non-null  int64
#  29  total_tracks                     11296 non-null  int64
#  30  album_type                       11296 non-null  object
#  31  image_url                        11296 non-null  object
#  32  artist_id                        11296 non-null  object
#  33  release_date_releases            11296 non-null  object
#  34  release_date_precision_releases  11296 non-null  object
#  35  name_artists                     11296 non-null  object
#  36  followers                        11296 non-null  float64
#  37  popularity_artists               11296 non-null  int64
#  38  artist_type                      11296 non-null  object
#  39  main_genre                       11296 non-null  object
#  40  genres                           11296 non-null  object
#  41  image_url_artists                11296 non-null  object
# dtypes: bool(1), float64(10), int64(9), object(22)
# memory usage: 3.5+ MB

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)
df5.sample(10)
# Out:
#                      song_id  duration_ms  key  mode  time_signature  \
# 3001  4vzYcDxBXAUPYDUna4BVeE       226133    8     1               4
# 1075  4WiiRw2PHMNQE0ad6y6GdD       224674   11     1               4
# 5736  3Cn1aiqSnvaj3FF4eFT80W       283400    1     0               4
# 4074  02D9uD9WQb834Lb54xCvDS       290067    2     0               4
# 4845  1kwvV2LoPN0S7d66WeyTdY       276440   10     1               4
# 9903  15vsWnfozeZsZQtcVeHMCn       175067    3     1               4
# 9098  30MyA7RaAa7ofOOxzew5vf       204813    7     1               3
# 8844  4RFqi5JQduiSlRZCVlUDGH       184333    7     1               4
# 9819  54dLJWk0He1SHiNaBXUav1       121213    5     1               4
# 6079  6vyZfDArwB7MdASSjFsl9y       292120    3     1               4
#
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 3001      0.750000         0.498   0.493          0.000000    0.1150
# 1075      0.000532         0.614   0.938          0.000000    0.3680
# 5736      0.364000         0.624   0.415          0.000160    0.0649
# 4074      0.343000         0.695   0.638          0.000000    0.6350
# 4845      0.314000         0.624   0.600          0.000000    0.0890
# 9903      0.646000         0.642   0.509          0.000000    0.0432
# 9098      0.839000         0.364   0.196          0.000272    0.0962
# 8844      0.039600         0.609   0.624          0.000168    0.2770
# 9819      0.738000         0.705   0.666          0.000000    0.1770
# 6079      0.589000         0.614   0.366          0.000058    0.0890
#
#       loudness  speechiness  valence    tempo  \
# 3001    -7.748       0.0369    0.222  146.049
# 1075    -4.461       0.0611    0.607  100.058
# 5736   -13.167       0.0460    0.594   85.110
# 4074    -7.891       0.0458    0.701  118.106
# 4845    -8.646       0.0307    0.576  115.849
# 9903   -10.192       0.0354    0.652  139.256
# 9098   -15.367       0.0378    0.341  199.720
# 8844   -11.717       0.0292    0.691  123.191
# 9819    -9.704       0.0478    0.924  147.819
# 6079   -10.925       0.0325    0.304  136.388
#
#                                                  lyrics  \
# 3001  ['[Verse 1]\nEverybody\'s looking for that som...
# 1075  ["[Verse 1]\nCall it a split cause you know th...
# 5736  ["[Chorus:]\nSomeone just like me\nRunning int...
# 4074  ["[Verse 1: JoJo]\nPromises you made me\nAll t...
# 4845  ["Driving past your house again I feel the sam...
# 9903  ["[R. Stevie Moore as Self]\nListen!\n\n[R. St...
# 9098  ["You're just too good to be true\nCan't take ...
# 8844  ["[Intro]\nIt don't come easy\nYou know it don...
# 9819  ['[Intro]\nI happen to believe in life after d...
# 6079  ["[Verse 1]\nOne more night, one more night\nO...
#
#                        song_name  \
# 3001        Flying Without Wings
# 1075                   Chocolate
# 5736                     Someone
# 4074               Love U 4 Life
# 4845         Love At First Sight
# 9903    Just a Little Bit Better
# 9098  Can't Take My Eyes Off You
# 8844          It Don't Come Easy
# 9819                Tippy Toeing
# 6079              One More Night
#
#                                              billboard  \
# 3001        ('Flying Without Wings', 'Ruben Studdard')
# 1075                         ('Chocolate', 'The 1975')
# 5736                         ('Someone', 'El DeBarge')
# 4074                       ('Love U 4 Life', 'Jodeci')
# 4845                   ('Love At First Sight', 'Styx')
# 9903  ('Just A Little Bit Better', "Herman's Hermits")
# 9098    ("Can't Take My Eyes Off You", 'Nancy Wilson')
# 8844             ("It Don't Come Easy", 'Ringo Starr')
# 9819               ('Tippy Toeing', 'The Harden Trio')
# 6079                ('One More Night', 'Phil Collins')
#
#                                              artists  popularity  explicit  \
# 3001    {'0H0yrKDty3I7pPrNUSH3wW': 'Ruben Studdard'}          33     False
# 1075          {'3mIj9lX2MWuHmhNCA7LSCW': 'The 1975'}          65     False
# 5736        {'5xO4f5QyPMYnCPRyRveBSD': 'El DeBarge'}          43     False
# 4074            {'1eNkUXHPaXyuyC8NAgzykK': 'Jodeci'}          52     False
# 4845              {'4salDzkGmfycRqNUbyBphh': 'Styx'}          19     False
# 9903  {'48YxSlb23RAaCd4RyHcV9V': "Herman's Hermits"}          13     False
# 9098      {'2JfVCMa3FlvQRlLT5uH9zb': 'Nancy Wilson'}           7     False
# 8844       {'6DbJi8AcN5ANdtvJcwBSw8': 'Ringo Starr'}          52     False
# 9819   {'4NpvTrjODQU5pCxWeMlXQc': 'The Harden Trio'}          11     False
# 6079      {'4lxfqrEsLX6N1N4OCSkILp': 'Phil Collins'}          40     False
#
#      song_type                album_id  track_number release_date  \
# 3001      Solo  47bXgGhWuf860hvtAHX1Vr            13   2003-08-22
# 1075      Solo  6Z1zv6Hw9bdvSoxI5uYk2h             4   2013-01-01
# 5736      Solo  4WtFh6jQ53Pn0PdkUhWgYK             4   1986-01-01
# 4074      Solo  5tincGtQaRD1QoXAT0PELz            20   1995-01-01
# 4845      Solo  6dLlnu5TPxD74g7w8SfnqF             4   1990-01-01
# 9903      Solo  4mK6pUS5somF93tMDs1HAZ            10   1997-10-13
# 9098      Solo  0dVExMkVVz7NWYqOIdDtrl             4   1969-01-01
# 8844      Solo  6zjenDV68SpvM3oEhorTDm            12   1973-01-01
# 9819      Solo  4MBDuPbpuIJRgq94gyAisL             1         1966
# 6079      Solo  7KZTL6gFUUCzNw4FfjVqCF             3   2004-09-14
#
#      release_date_precision                                    name  \
# 3001                    day                                 Soulful
# 1075                    day                                The 1975
# 5736                    day                              El DeBarge
# 4074                    day    The Show, The After Party, The Hotel
# 4845                    day                     Edge Of The Century
# 9903                    day       The Very Best Of Herman's Hermits
# 9098                    day                             Hurt So Bad
# 8844                    day                                   Ringo
# 9819                   year                            Tippy Toeing
# 6079                    day  Love Songs (A Compilation Old and New)
#
#                               billboard_albums  \
# 3001                                   Soulful
# 1075                                  The 1975
# 5736                                El DeBarge
# 4074      The Show, The After Party, The Hotel
# 4845                       Edge Of The Century
# 9903              The Best Of Herman's Hermits
# 9098                               Hurt So Bad
# 8844                                     Ringo
# 9819                              Tippy Toeing
# 6079  Love Songs: A Compilation... Old And New
#
#                                       artists_albums  popularity_albums  \
# 3001    {'0H0yrKDty3I7pPrNUSH3wW': 'Ruben Studdard'}                 39
# 1075          {'3mIj9lX2MWuHmhNCA7LSCW': 'The 1975'}                 72
# 5736        {'5xO4f5QyPMYnCPRyRveBSD': 'El DeBarge'}                 43
# 4074            {'1eNkUXHPaXyuyC8NAgzykK': 'Jodeci'}                 60
# 4845              {'4salDzkGmfycRqNUbyBphh': 'Styx'}                 43
# 9903  {'48YxSlb23RAaCd4RyHcV9V': "Herman's Hermits"}                 55
# 9098      {'2JfVCMa3FlvQRlLT5uH9zb': 'Nancy Wilson'}                 10
# 8844       {'6DbJi8AcN5ANdtvJcwBSw8': 'Ringo Starr'}                 57
# 9819   {'4NpvTrjODQU5pCxWeMlXQc': 'The Harden Trio'}                 10
# 6079      {'4lxfqrEsLX6N1N4OCSkILp': 'Phil Collins'}                 58
#
#       total_tracks   album_type  \
# 3001            14        album
# 1075            16        album
# 5736            10        album
# 4074            22        album
# 4845            10        album
# 9903            25        album
# 9098            10        album
# 8844            13        album
# 9819            11        album
# 6079            24  compilation
#
#                                               image_url  \
# 3001  https://i.scdn.co/image/d58c09dfca858e3c1de08e...
# 1075  https://i.scdn.co/image/3ec29e8d84254ddbb11df4...
# 5736  https://i.scdn.co/image/b15738ee524e644adfe680...
# 4074  https://i.scdn.co/image/63aadd568fa7c64a391de5...
# 4845  https://i.scdn.co/image/054e1eae1baf5d21634495...
# 9903  https://i.scdn.co/image/3b3fe54b332fc8a0b63287...
# 9098  https://i.scdn.co/image/4193470150f0d900c44383...
# 8844  https://i.scdn.co/image/a06914eaa323bc76071e1f...
# 9819  https://i.scdn.co/image/17e7eb1c1da62b5f2f2550...
# 6079  https://i.scdn.co/image/e79a460778c8ac375ea42c...
#
#                    artist_id release_date_releases  \
# 3001  0H0yrKDty3I7pPrNUSH3wW            2003-08-22
# 1075  3mIj9lX2MWuHmhNCA7LSCW            2013-01-01
# 5736  5xO4f5QyPMYnCPRyRveBSD            1986-01-01
# 4074  1eNkUXHPaXyuyC8NAgzykK            1995-01-01
# 4845  4salDzkGmfycRqNUbyBphh            1990-01-01
# 9903  48YxSlb23RAaCd4RyHcV9V            1997-10-13
# 9098  2JfVCMa3FlvQRlLT5uH9zb            1969-01-01
# 8844  6DbJi8AcN5ANdtvJcwBSw8            1973-01-01
# 9819  4NpvTrjODQU5pCxWeMlXQc                  1966
# 6079  4lxfqrEsLX6N1N4OCSkILp            2004-09-14
#
#      release_date_precision_releases      name_artists  followers  \
# 3001                             day    Ruben Studdard    70446.0
# 1075                             day          The 1975  3395560.0
# 5736                             day        El DeBarge   128887.0
# 4074                             day            Jodeci   946185.0
# 4845                             day              Styx   772094.0
# 9903                             day  Herman's Hermits   198530.0
# 9098                             day      Nancy Wilson    92662.0
# 8844                             day       Ringo Starr   413308.0
# 9819                            year   The Harden Trio       84.0
# 6079                             day      Phil Collins  2158646.0
#
#       popularity_artists artist_type               main_genre  \
# 3001                  45      singer               gospel r&b
# 1075                  82        band  modern alternative rock
# 5736                  47      singer                 neo soul
# 4074                  61        band                dance pop
# 4845                  67        band               album rock
# 9903                  56        band          adult standards
# 9098                  54      singer          adult standards
# 8844                  55        band               album rock
# 9819                   8        band                        -
# 6079                  80      singer              mellow gold
#
#                                                  genres  \
# 3001  ['gospel r&b', 'neo soul', 'new jack swing', '...
# 1075  ['modern alternative rock', 'nu gaze', 'pop', ...
# 5736  ['neo soul', 'new jack swing', 'quiet storm', ...
# 4074  ['dance pop', 'funk', 'hip hop', 'hip pop', 'n...
# 4845  ['album rock', 'art rock', 'classic rock', 'ha...
# 9903  ['adult standards', 'brill building pop', 'bri...
# 9098  ['adult standards', 'cool jazz', 'jazz', 'loun...
# 8844  ['album rock', 'bubblegum pop', 'classic rock'...
# 9819                                                 []
# 6079                       ['mellow gold', 'soft rock']
#
#                                       image_url_artists
# 3001  https://i.scdn.co/image/7b93e869dfdbb5f16af8bf...
# 1075  https://i.scdn.co/image/8a3d6828ab99babae5669e...
# 5736  https://i.scdn.co/image/7df8fb62afd1287636381c...
# 4074  https://i.scdn.co/image/b4600df5d140fabc3e5967...
# 4845  https://i.scdn.co/image/cc444d0ab1d2f3d5e82a38...
# 9903  https://i.scdn.co/image/661423f5d26a62a4a29474...
# 9098  https://i.scdn.co/image/a1eb2886954d4c6bf9b218...
# 8844  https://i.scdn.co/image/bf05c9ed47f404fda1e5e8...
# 9819  https://i.scdn.co/image/17e7eb1c1da62b5f2f2550...
# 6079  https://i.scdn.co/image/31fbe64783eb5d49316164...

# %%
#drop unecessary columns 
columns= ['image_url_artists','genres','image_url','album_id','song_id']
df5= df5.drop(columns=columns,axis=1)

# %%
df5.isnull().sum()
# Out:
# duration_ms                          0
# key                                  0
# mode                                 0
# time_signature                       0
# acousticness                         0
# danceability                         0
# energy                               0
# instrumentalness                     0
# liveness                             0
# loudness                             0
# speechiness                          0
# valence                              0
# tempo                                0
# lyrics                             256
# song_name                            0
# billboard                            0
# artists                              0
# popularity                           0
# explicit                             0
# song_type                            0
# track_number                         0
# release_date                         0
# release_date_precision               0
# name                                 0
# billboard_albums                     0
# artists_albums                       0
# popularity_albums                    0
# total_tracks                         0
# album_type                           0
# artist_id                            0
# release_date_releases                0
# release_date_precision_releases      0
# name_artists                         0
# followers                            0
# popularity_artists                   0
# artist_type                          0
# main_genre                           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df5.shape
# Out:
# (11296, 37)

# %%
df5=df5.dropna()
df5.shape
# Out:
# (11040, 37)

# %%
df5.isnull().sum()
# Out:
# duration_ms                        0
# key                                0
# mode                               0
# time_signature                     0
# acousticness                       0
# danceability                       0
# energy                             0
# instrumentalness                   0
# liveness                           0
# loudness                           0
# speechiness                        0
# valence                            0
# tempo                              0
# lyrics                             0
# song_name                          0
# billboard                          0
# artists                            0
# popularity                         0
# explicit                           0
# song_type                          0
# track_number                       0
# release_date                       0
# release_date_precision             0
# name                               0
# billboard_albums                   0
# artists_albums                     0
# popularity_albums                  0
# total_tracks                       0
# album_type                         0
# artist_id                          0
# release_date_releases              0
# release_date_precision_releases    0
# name_artists                       0
# followers                          0
# popularity_artists                 0
# artist_type                        0
# main_genre                         0
# dtype: int64

# %%
numerical_data= df5.select_dtypes(include=['int64','float64'])
object_bool_data= df5.select_dtypes(include=['object','bool'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# basic statistics
display(df5.describe())

# Plotting distributions of numerical features
numerical_data.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# Correlation matrix
corr_matrix = numerical_data.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Independent Variables')
plt.show()
# Out:
#         duration_ms           key          mode  time_signature  acousticness  \
# count  1.104000e+04  11040.000000  11040.000000    11040.000000  11040.000000
# mean   2.385800e+05      5.192029      0.718931        3.955163      0.232321
# std    6.525111e+04      3.568197      0.449541        0.266634      0.243825
# min    4.048000e+04      0.000000      0.000000        0.000000      0.000003
# 25%    1.995035e+05      2.000000      0.000000        4.000000      0.033275
# 50%    2.313535e+05      5.000000      1.000000        4.000000      0.137000
# 75%    2.670400e+05      8.000000      1.000000        4.000000      0.371000
# max    1.561133e+06     11.000000      1.000000        5.000000      0.982000
#
#        danceability        energy  instrumentalness      liveness  \
# count  11040.000000  11040.000000      11040.000000  11040.000000
# mean       0.602694      0.643306          0.024992      0.184800
# std        0.147285      0.192811          0.111567      0.153505
# min        0.000000      0.022000          0.000000      0.013600
# 25%        0.507000      0.503000          0.000000      0.086800
# 50%        0.609000      0.663000          0.000007      0.126000
# 75%        0.705000      0.800000          0.000609      0.239250
# max        0.988000      0.996000          0.962000      0.997000
#
#            loudness   speechiness       valence         tempo    popularity  \
# count  11040.000000  11040.000000  11040.000000  11040.000000  11040.000000
# mean      -8.455945      0.069412      0.592809    120.549964     43.806341
# std        3.569172      0.076789      0.235852     27.811213     18.586664
# min      -27.010000      0.000000      0.000000      0.000000      0.000000
# 25%      -10.872750      0.031900      0.405000     99.683500     31.000000
# 50%       -7.982500      0.040750      0.612000    119.219500     45.000000
# 75%       -5.623750      0.064025      0.787000    136.486750     58.000000
# max       -0.517000      0.950000      0.989000    231.028000     86.000000
#
#        track_number  popularity_albums  total_tracks     followers  \
# count  11040.000000       11040.000000  11040.000000  1.104000e+04
# mean       5.169928          54.242210     14.357065  2.601577e+06
# std        4.448202          16.919954      8.245851  5.769297e+06
# min        1.000000           0.000000      1.000000  0.000000e+00
# 25%        2.000000          43.000000     10.000000  1.751400e+05
# 50%        4.000000          56.000000     12.000000  6.771100e+05
# 75%        7.000000          67.000000     16.000000  2.159060e+06
# max       69.000000          95.000000    127.000000  4.980672e+07
#
#        popularity_artists
# count        11040.000000
# mean            65.462228
# std             17.116966
# min              0.000000
# 25%             57.000000
# 50%             68.000000
# 75%             77.000000
# max            100.000000

# %% [markdown]
# ### Which Artist Has the Highest Average Popularity and Followers?

# %%
# Grouping by artist_id and calculating the mean popularity for each artist
artist_popularity = df5.groupby('artist_id')['popularity'].mean().reset_index()

# Merging artist popularity with the artists df for artist names
artist_popularity = artist_popularity.merge(artists[['artist_id', 'name']], on='artist_id')

# Sort artists by popularity
artist_popularity = artist_popularity.sort_values(by='popularity', ascending=False)

# Displaying the top 10 artists with similar popularity
artist_popularity.head(15)
# Out:
#                    artist_id  popularity               name
# 1707  4lDBihdpMlOalxy1jkUbPl        83.0               Grey
# 1542  4IWBUUAFIplrNtaOHcJPRM        82.0       James Arthur
# 2406  6qqNVTkY8uBg9cP3Jd7DAH        82.0      Billie Eilish
# 882   2RDOrhPqAM4jzTRCEb19qX        81.0          Sheck Wes
# 2236  6M2wZ9GZgrQXHCFfjv46we        81.0           Dua Lipa
# 2132  64M6ah0SkkRsnPGtGiRAbb        80.0         Bebe Rexha
# 2591  7Ln80lUS6He07XvHI8qqHH        80.0     Arctic Monkeys
# 1534  4GvEc3ANtPPjt1ZJllr5Zl        80.0              Bazzi
# 2455  6ydoSd3N2mwgwBHtF6K7eX        80.0        Calum Scott
# 2540  7CajNmpbOovFoOoasH2HaY        79.0      Calvin Harris
# 1449  40LHVA5BTQp9RxHOQ9JPYj        79.0      Lauren Daigle
# 2672  7n2wHs1TKAczGzO7Dd2rGr        79.0       Shawn Mendes
# 1701  4kI8Ie27vjvonwaB2ePh8T        79.0  Portugal. The Man
# 2235  6LuN9FCkKOj5PcnpouEgny        78.5             Khalid
# 2342  6fOMl44jA4Sp5b9PpYCkzz        78.5                 NF

# %%
# Grouping by artist and calculating the mean popularity and followers
artist_popularity_followers = df5.groupby('name_artists')['followers'].mean()

# Sorting by popularity in descending order and selecting the top 10 artists
top_10_artists = artist_popularity_followers.sort_values(ascending=False).head(10)

# Plotting
plt.figure(figsize=(10, 6))
top_10_artists.plot(kind='bar', ax=plt.gca())
plt.title('Top 10 Artists by Mean followers')
plt.xlabel('Artist')
plt.ylabel('Mean Values')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df5, x='artist_type')
plt.title('Count of Artist Types in the data')
# Out:
# Text(0.5, 1.0, 'Count of Artist Types in the data')

# %%
df5[['album_type','song_type']].dtypes
# Out:
# album_type    object
# song_type     object
# dtype: object

# %% [markdown]
# ## Whict type of song had the highest or lowest album, artist and explicit condition?

# %%
obj=df5[['song_type','album_type','explicit','artist_type']]

# %%
# Columns to plot
columns = ['song_type', 'album_type', 'explicit', 'artist_type']

# Plotting
plt.figure(figsize=(12, 8))

for i, col in enumerate(columns, start=1):
    plt.subplot(len(columns), 1, i)
    sns.countplot(data=obj, x=col, hue='song_type')
    plt.title(f'Count Plot of {col} with Hue "song_type"')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.legend(title='song_type', loc='upper right')

plt.tight_layout()
plt.show()

# %%
dropcol = ['artists_albums', 'artists', 'billboard','billboard_albums' , 'artist_id', 'release_date_precision', 'release_date', 'track_number', 'release_date_precision_releases', 'release_date_releases']

df5.drop(dropcol, axis=1, inplace=True)

# %%
categ_cols = [col for col in df5 if df5[col].dtype == 'object']
num_cols = [col for col in df5 if df5[col].dtype != 'object']
print(f"Category Columns are: {categ_cols}")
print(f"Numeric Columns are: {num_cols}")
# Out:
# Category Columns are: ['lyrics', 'song_name', 'song_type', 'name', 'album_type', 'name_artists', 'artist_type', 'main_genre']
# Numeric Columns are: ['duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo', 'popularity', 'explicit', 'popularity_albums', 'total_tracks', 'followers', 'popularity_artists']

# %%
categ= ['album_type', 'artist_type', 'song_type', 'main_genre', 'explicit']

df5[categ] = df5[categ].astype('category')

# %%
le = OrdinalEncoder()

df5[categ] = le.fit_transform(df5[categ])

# %%
df5.dtypes
# Out:
# duration_ms             int64
# key                     int64
# mode                    int64
# time_signature          int64
# acousticness          float64
# danceability          float64
# energy                float64
# instrumentalness      float64
# liveness              float64
# loudness              float64
# speechiness           float64
# valence               float64
# tempo                 float64
# lyrics                 object
# song_name              object
# popularity              int64
# explicit              float64
# song_type             float64
# name                   object
# popularity_albums       int64
# total_tracks            int64
# album_type            float64
# name_artists           object
# followers             float64
# popularity_artists      int64
# artist_type           float64
# main_genre            float64
# dtype: object

# %% [markdown]
# ##  Silhoette Score
# The Silhouette Coefficient is calculated using the mean intra-cluster distance (a) and the mean nearest-cluster distance (b) for each sample. The Silhouette Coefficient for a sample is (b - a) / max(a, b). To clarify, b is the distance between a sample and the nearest cluster that the sample is not a part of. Note that Silhouette Coefficient is only defined if number of labels is 2 <= n_labels <= n_samples - 1.
#
# This function returns the mean Silhouette Coefficient over all samples. To obtain the values for each sample, use silhouette_samples.
#
# The best value is 1 and the worst value is -1. Values near 0 indicate overlapping clusters. Negative values generally indicate that a sample has been assigned to the wrong cluster, as a different cluster is more similar.
#
# ## Davies-Bouldin Index Score
# The score is defined as the average similarity measure of each cluster with its most similar cluster, where similarity is the ratio of within-cluster distances to between-cluster distances. Thus, clusters which are farther apart and less dispersed will result in a better score.
# The minimum score is zero, with lower values indicating better clustering.

# %%
dropa =['name_artists', 'name', 'lyrics', 'song_name']

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init="auto")
labels = kmeans.fit_predict(df5.drop(dropa, axis=1))
sscore = silhouette_score(df5.drop(dropa, axis=1), labels)
dscore = davies_bouldin_score(df5.drop(dropa, axis=1), labels)

print(f"Silhoette Score is: {sscore}")
print(f"Davies-Bouldin Index Score is: {dscore}")
# Out:
# Silhoette Score is: 0.743597827716953
# Davies-Bouldin Index Score is: 0.4926745885179865
